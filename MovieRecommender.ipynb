# %%
import numpy as np
import pandas as pd
import scipy.stats as st
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.spatial.distance import cdist
from matplotlib import pyplot as plt
from fancyimpute import SoftImpute, BiScaler

# %% [markdown]
# # Movie Recommender
# ## User Based

# %%
def topFive(s):
    l = pd.DataFrame(
        np.c_[
            s.apply(lambda x:list(np.sort(np.array(x))[::-1][:5]), axis=1).to_list(),
            s.apply(lambda x:list(s.columns[np.array(x).argsort()[::-1][:5]]), axis=1).to_list()
        ]
    ) [[0, 5, 1, 6, 2, 7, 3, 8, 4, 9]].reset_index()
    l.columns = [
        'User',
        'Movie1Score', 'Movie1', 'Movie2Score', 'Movie2','Movie3Score', 'Movie3',
        'Movie4Score', 'Movie4', 'Movie5Score', 'Movie5',
    ]
    return l

# %%
df = pd.read_excel("data/movie.xlsx", header=None).transpose()
df.columns = df.iloc[0]
df = pd.get_dummies(
    df.drop(df.index[[0,1]]).drop(df.columns[[0, 3, 16]], axis=1),
    columns = ["Gender", "Favourite Colour"]).astype('int32')
movies = df[df.columns[12:-9]].reset_index().drop(['index'], axis=1)

# %%
def userRecommender(method):
    adjMatrix = np.exp(-(cdist(df, df, method)**2))
    s = adjMatrix@movies
    s[movies != 0] = 0
    den = adjMatrix@(movies != 0).astype('int32')
    den[den==0] = 1
    s = (s / den).round(3)
    return topFive(s)

# %%
a1 = userRecommender('euclid')
a2 = userRecommender('cityblock')
a3 = userRecommender('hamming')

# %% [markdown]
# ## Movie Based

# %%
dfb = df.T.copy()
users = df.copy()
users[users.columns[12:-9]] = users[users.columns[12:-9]]
users = users.T

# %%
def movieRecommender(method):
    adjMatrix = np.exp(-(cdist(dfb, dfb, method)**2))
    s = adjMatrix@users
    t = np.full(s.shape, False)
    t[12:-9] = users.iloc[12:-9]==0
    s[np.invert(t)] = 0
    den = adjMatrix@(users != 0).astype('int32')
    den[den==0] = 1
    s = (s / den).round(3).iloc[12:-9].T
    s.columns = movies.columns
    return topFive(s)

# %%
b1 = movieRecommender('euclid')
b2 = movieRecommender('cityblock')
b3 = movieRecommender('hamming')

# %%
dfc = df[df.columns[12:-9]]
imputed = (dfc == 0)
df_nan = dfc.replace(0, np.nan).to_numpy()
df_filled = SoftImpute().fit_transform(BiScaler().fit_transform(df_nan))
# Out:
# [BiScaler] Initial log residual value = 6.805177
# [BiScaler] Iter 1: log residual = 0.172665, log improvement ratio=6.632512
# [BiScaler] Iter 2: log residual = -1.433144, log improvement ratio=1.605809
# [BiScaler] Iter 3: log residual = -3.248376, log improvement ratio=1.815232
# [BiScaler] Iter 4: log residual = -4.781844, log improvement ratio=1.533468
# [BiScaler] Iter 5: log residual = -6.203882, log improvement ratio=1.422038
# [BiScaler] Iter 6: log residual = -7.570635, log improvement ratio=1.366753
# [BiScaler] Iter 7: log residual = -8.908895, log improvement ratio=1.338260
# [BiScaler] Iter 8: log residual = -10.231820, log improvement ratio=1.322925
# [BiScaler] Iter 9: log residual = -11.545135, log improvement ratio=1.313316
# [BiScaler] Iter 10: log residual = -12.851103, log improvement ratio=1.305967
# [BiScaler] Iter 11: log residual = -14.150488, log improvement ratio=1.299386
# [BiScaler] Iter 12: log residual = -15.443482, log improvement ratio=1.292994
# [BiScaler] Iter 13: log residual = -16.730109, log improvement ratio=1.286627
# [BiScaler] Iter 14: log residual = -18.010409, log improvement ratio=1.280300
# [BiScaler] Iter 15: log residual = -19.284502, log improvement ratio=1.274092
# [BiScaler] Iter 16: log residual = -20.552600, log improvement ratio=1.268098
# [BiScaler] Iter 17: log residual = -21.814999, log improvement ratio=1.262400
# [BiScaler] Iter 18: log residual = -23.072056, log improvement ratio=1.257057
# [BiScaler] Iter 19: log residual = -24.324164, log improvement ratio=1.252107
# [BiScaler] Iter 20: log residual = -25.571731, log improvement ratio=1.247567
# [BiScaler] Iter 21: log residual = -26.815168, log improvement ratio=1.243437
# [BiScaler] Iter 22: log residual = -28.054870, log improvement ratio=1.239703
# [BiScaler] Iter 23: log residual = -29.291216, log improvement ratio=1.236345
# [BiScaler] Iter 24: log residual = -30.524555, log improvement ratio=1.233339
# [BiScaler] Iter 25: log residual = -31.755211, log improvement ratio=1.230656
# [BiScaler] Iter 26: log residual = -32.983478, log improvement ratio=1.228267
# [BiScaler] Iter 27: log residual = -34.209622, log improvement ratio=1.226145
# [BiScaler] Iter 28: log residual = -35.433884, log improvement ratio=1.224262
# [BiScaler] Iter 29: log residual = -36.656477, log improvement ratio=1.222592
# [BiScaler] Iter 30: log residual = -37.877593, log improvement ratio=1.221116
# [BiScaler] Iter 31: log residual = -39.097400, log improvement ratio=1.219807
# [BiScaler] Iter 32: log residual = -40.316052, log improvement ratio=1.218652
# [BiScaler] Iter 33: log residual = -41.533682, log improvement ratio=1.217631
# [BiScaler] Iter 34: log residual = -42.750417, log improvement ratio=1.216735
# [BiScaler] Iter 35: log residual = -43.966356, log improvement ratio=1.215939
# [BiScaler] Iter 36: log residual = -45.181562, log improvement ratio=1.215206
# [BiScaler] Iter 37: log residual = -46.396150, log improvement ratio=1.214588
# [BiScaler] Iter 38: log residual = -47.610164, log improvement ratio=1.214013
# [BiScaler] Iter 39: log residual = -48.823903, log improvement ratio=1.213740
# [BiScaler] Iter 40: log residual = -50.037037, log improvement ratio=1.213134
# [BiScaler] Iter 41: log residual = -51.248880, log improvement ratio=1.211843
# [BiScaler] Iter 42: log residual = -52.462561, log improvement ratio=1.213681
# [BiScaler] Iter 43: log residual = -53.676188, log improvement ratio=1.213626
# [BiScaler] Iter 44: log residual = -54.883144, log improvement ratio=1.206957
# [BiScaler] Iter 45: log residual = -56.096447, log improvement ratio=1.213303
# [BiScaler] Iter 46: log residual = -57.309917, log improvement ratio=1.213470
# [BiScaler] Iter 47: log residual = -58.526141, log improvement ratio=1.216223
# [BiScaler] Iter 48: log residual = -59.690306, log improvement ratio=1.164165
# [BiScaler] Iter 49: log residual = -60.895350, log improvement ratio=1.205045
# [BiScaler] Iter 50: log residual = -62.128951, log improvement ratio=1.233601
# [BiScaler] Iter 51: log residual = -63.282230, log improvement ratio=1.153279
# [BiScaler] Iter 52: log residual = -64.401463, log improvement ratio=1.119232
# [BiScaler] Iter 53: log residual = -64.484170, log improvement ratio=0.082708
# [BiScaler] Iter 54: log residual = -65.348813, log improvement ratio=0.864643
# [BiScaler] Iter 55: log residual = -65.425291, log improvement ratio=0.076478
# [BiScaler] Iter 56: log residual = -65.870696, log improvement ratio=0.445405
# [BiScaler] Iter 57: log residual = -65.629699, log improvement ratio=-0.240997
# [SoftImpute] Max Singular Value of X_init = 9.298268
# [SoftImpute] Iter 1: observed MAE=0.028419 rank=19
# [SoftImpute] Iter 2: observed MAE=0.028468 rank=19
# [SoftImpute] Iter 3: observed MAE=0.028522 rank=19
# [SoftImpute] Iter 4: observed MAE=0.028571 rank=19
# [SoftImpute] Iter 5: observed MAE=0.028615 rank=19
# [SoftImpute] Iter 6: observed MAE=0.028655 rank=19
# [SoftImpute] Iter 7: observed MAE=0.028690 rank=19
# [SoftImpute] Iter 8: observed MAE=0.028721 rank=19
# [SoftImpute] Iter 9: observed MAE=0.028749 rank=19
# [SoftImpute] Iter 10: observed MAE=0.028776 rank=19
# [SoftImpute] Iter 11: observed MAE=0.028802 rank=19
# [SoftImpute] Iter 12: observed MAE=0.028825 rank=19
# [SoftImpute] Iter 13: observed MAE=0.028844 rank=19
# [SoftImpute] Iter 14: observed MAE=0.028861 rank=19
# [SoftImpute] Iter 15: observed MAE=0.028876 rank=19
# [SoftImpute] Iter 16: observed MAE=0.028889 rank=19
# [SoftImpute] Iter 17: observed MAE=0.028901 rank=19
# [SoftImpute] Iter 18: observed MAE=0.028913 rank=19
# [SoftImpute] Iter 19: observed MAE=0.028924 rank=19
# [SoftImpute] Iter 20: observed MAE=0.028933 rank=19
# [SoftImpute] Iter 21: observed MAE=0.028941 rank=19
# [SoftImpute] Iter 22: observed MAE=0.028947 rank=19
# [SoftImpute] Iter 23: observed MAE=0.028953 rank=19
# [SoftImpute] Iter 24: observed MAE=0.028958 rank=19
# [SoftImpute] Iter 25: observed MAE=0.028962 rank=19
# [SoftImpute] Iter 26: observed MAE=0.028965 rank=19
# [SoftImpute] Iter 27: observed MAE=0.028968 rank=19
# [SoftImpute] Iter 28: observed MAE=0.028970 rank=19
# [SoftImpute] Iter 29: observed MAE=0.028971 rank=19
# [SoftImpute] Iter 30: observed MAE=0.028971 rank=19
# [SoftImpute] Iter 31: observed MAE=0.028971 rank=19
# [SoftImpute] Iter 32: observed MAE=0.028970 rank=19
# [SoftImpute] Iter 33: observed MAE=0.028970 rank=19
# [SoftImpute] Iter 34: observed MAE=0.028971 rank=19
# [SoftImpute] Iter 35: observed MAE=0.028974 rank=19
# [SoftImpute] Iter 36: observed MAE=0.028975 rank=19
# [SoftImpute] Iter 37: observed MAE=0.028977 rank=19
# [SoftImpute] Iter 38: observed MAE=0.028925 rank=18
# [SoftImpute] Iter 39: observed MAE=0.028847 rank=18
# [SoftImpute] Iter 40: observed MAE=0.028802 rank=18
# [SoftImpute] Iter 41: observed MAE=0.028777 rank=18
# [SoftImpute] Iter 42: observed MAE=0.028760 rank=18
# [SoftImpute] Iter 43: observed MAE=0.028748 rank=18
# [SoftImpute] Iter 44: observed MAE=0.028739 rank=18
# [SoftImpute] Iter 45: observed MAE=0.028732 rank=18
# [SoftImpute] Iter 46: observed MAE=0.028727 rank=18
# [SoftImpute] Iter 47: observed MAE=0.028723 rank=18
# [SoftImpute] Iter 48: observed MAE=0.028720 rank=18
# [SoftImpute] Iter 49: observed MAE=0.028718 rank=18
# [SoftImpute] Iter 50: observed MAE=0.028716 rank=18
# [SoftImpute] Iter 51: observed MAE=0.028714 rank=18
# [SoftImpute] Iter 52: observed MAE=0.028713 rank=18
# [SoftImpute] Iter 53: observed MAE=0.028712 rank=18
# [SoftImpute] Iter 54: observed MAE=0.028711 rank=18
# [SoftImpute] Iter 55: observed MAE=0.028710 rank=18
# [SoftImpute] Iter 56: observed MAE=0.028710 rank=18
# [SoftImpute] Iter 57: observed MAE=0.028709 rank=18
# [SoftImpute] Iter 58: observed MAE=0.028709 rank=18
# [SoftImpute] Iter 59: observed MAE=0.028710 rank=18
# [SoftImpute] Iter 60: observed MAE=0.028710 rank=18
# [SoftImpute] Iter 61: observed MAE=0.028710 rank=18
# [SoftImpute] Iter 62: observed MAE=0.028711 rank=18
# [SoftImpute] Iter 63: observed MAE=0.028711 rank=18
# [SoftImpute] Iter 64: observed MAE=0.028712 rank=18
# [SoftImpute] Iter 65: observed MAE=0.028713 rank=18
# [SoftImpute] Iter 66: observed MAE=0.028714 rank=18
# [SoftImpute] Iter 67: observed MAE=0.028715 rank=18
# [SoftImpute] Iter 68: observed MAE=0.028716 rank=18
# [SoftImpute] Iter 69: observed MAE=0.028717 rank=18
# [SoftImpute] Iter 70: observed MAE=0.028718 rank=18
# [SoftImpute] Iter 71: observed MAE=0.028718 rank=18
# [SoftImpute] Iter 72: observed MAE=0.028719 rank=18
# [SoftImpute] Iter 73: observed MAE=0.028720 rank=18
# [SoftImpute] Iter 74: observed MAE=0.028721 rank=18
# [SoftImpute] Iter 75: observed MAE=0.028721 rank=18
# [SoftImpute] Iter 76: observed MAE=0.028722 rank=18
# [SoftImpute] Iter 77: observed MAE=0.028722 rank=18
# [SoftImpute] Iter 78: observed MAE=0.028723 rank=18
# [SoftImpute] Iter 79: observed MAE=0.028724 rank=18
# [SoftImpute] Iter 80: observed MAE=0.028725 rank=18
# [SoftImpute] Iter 81: observed MAE=0.028726 rank=18
# [SoftImpute] Iter 82: observed MAE=0.028727 rank=18
# [SoftImpute] Iter 83: observed MAE=0.028728 rank=18
# [SoftImpute] Iter 84: observed MAE=0.028728 rank=18
# [SoftImpute] Iter 85: observed MAE=0.028729 rank=18
# [SoftImpute] Iter 86: observed MAE=0.028730 rank=18
# [SoftImpute] Iter 87: observed MAE=0.028731 rank=18
# [SoftImpute] Iter 88: observed MAE=0.028732 rank=18
# [SoftImpute] Iter 89: observed MAE=0.028733 rank=18
# [SoftImpute] Iter 90: observed MAE=0.028733 rank=18
# [SoftImpute] Iter 91: observed MAE=0.028734 rank=18
# [SoftImpute] Iter 92: observed MAE=0.028735 rank=18
# [SoftImpute] Iter 93: observed MAE=0.028735 rank=18
# [SoftImpute] Iter 94: observed MAE=0.028736 rank=18
# [SoftImpute] Iter 95: observed MAE=0.028737 rank=18
# [SoftImpute] Iter 96: observed MAE=0.028737 rank=18
# [SoftImpute] Iter 97: observed MAE=0.028738 rank=18
# [SoftImpute] Iter 98: observed MAE=0.028739 rank=18
# [SoftImpute] Iter 99: observed MAE=0.028739 rank=18
# [SoftImpute] Iter 100: observed MAE=0.028740 rank=18
# [SoftImpute] Stopped after iteration 100 for lambda=0.185965

# %%
df_filled[np.invert(imputed)] = 0
df_imp = pd.DataFrame(df_filled).round(3)
df_imp.columns = movies.columns
c = topFive(df_imp)

# %%
with pd.ExcelWriter('Recommender.xlsx') as writer:  
    a1.to_excel(writer, sheet_name='UserBased L2 Norm')
    a2.to_excel(writer, sheet_name='UserBased L1 Norm')
    a3.to_excel(writer, sheet_name='UserBased L0 Norm')
    b1.to_excel(writer, sheet_name='MovieBased L2 Norm')
    b2.to_excel(writer, sheet_name='MovieBased L1 Norm')
    b3.to_excel(writer, sheet_name='MovieBased L0 Norm')
    c.to_excel(writer, sheet_name='Top 5')
